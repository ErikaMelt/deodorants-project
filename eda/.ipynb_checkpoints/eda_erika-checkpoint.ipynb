# %% [markdown]
# ## Análisis de las ventas de desodorantes en aerosol

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio
from plot_functions import plot_sales_chart, plot_piechart

# %%
deodorants_df = pd.read_csv("../clean_data/deodorants_final_merged.csv",
                            parse_dates=['fecha_trans'])

# %%
deodorants_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8356436 entries, 0 to 8356435
# Data columns (total 27 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   idb                     int64
#  1   id_producto             int64
#  2   fecha_trans             datetime64[ns]
#  3   stock_unidades          int64
#  4   venta_unidades          int64
#  5   precio_unitario         float64
#  6   sigue_prod_en_rol       int64
#  7   cd_abast                int64
#  8   mov_month               int64
#  9   mov_year                int64
#  10  mov_weekday             int64
#  11  ventas_estimadas_promo  int64
#  12  nro_prom                int64
#  13  duracion_promo          int64
#  14  id_cadena               int64
#  15  desc_cadena             object
#  16  longitud                float64
#  17  latitud                 float64
#  18  local                   int64
#  19  punto_dist              int64
#  20  desc_producto           object
#  21  razon_social            object
#  22  id_region               int64
#  23  dia_semana              object
#  24  is_weekend              int64
#  25  tiene_promo             int64
#  26  estacion                object
# dtypes: datetime64[ns](1), float64(3), int64(18), object(5)
# memory usage: 1.7+ GB

# %%
filtered_df = deodorants_df[[
    'stock_unidades', 'venta_unidades', 'ventas_estimadas_promo',
    'precio_unitario', 'duracion_promo'
]]

# %%
stats = filtered_df.describe()

# %%
stats = stats.round(3)

# Create a Plotly table
table = go.Table(header=dict(values=['Statistic'] + list(stats.columns),
                              fill_color="lightsteelblue",
                              font=dict(color='white', size=14),
                              align='center'),
                 cells=dict(values=[['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max']] + [stats[col] for col in stats.columns],
                            fill_color='#f2f2f2',
                            font=dict(color='#404040', size=12),
                            align='center'))

# Create a layout for the table
layout = go.Layout(width=700, height=400)

# Create a figure object with the table and layout
fig = go.Figure(data=[table], layout=layout)

# Save the figure as an image file
pio.write_image(fig, 'images/deodorants_stats.png')

# %% [markdown]
# ### Preguntas

# %% [markdown]
# - ¿Cuáles son los productos con mayor volumen de ventas?

# %%
product_grouped_top10 = deodorants_df.groupby(
    ['id_producto', 'desc_producto', 'razon_social'])['venta_unidades'].sum().sort_values(
        ascending=False).nlargest(10).reset_index()
product_grouped_top10
# Out:
#    id_producto                                      desc_producto  \
# 0       342686  glade desodorante de ambientes lavander nueva ...
# 1       240911           poett ambiental lavanda nuevo d 0.377 kg
# 2       429883  glade desodorante de ambientes ocean oasis nue...
# 3       249486      glade toque rep lavandax2 9gr/6 lavanda 9 grm
# 4       342745  glade desodorante de ambientes jazmin nueva fo...
# 5       228217      glade toque rep limon 12mlx12 repuesto 12 mlt
# 6       242234  poett ambiental suavidad de algodon nuevo d 0....
# 7       447299  glade desodorante de ambientes paraiso azul 1 ...
# 8       292949  glade toque desodorante de ambientes ma�ana ca...
# 9       242231         poett ambiental primavera nuevo d 0.377 kg
#
#                        razon_social  venta_unidades
# 0  s. c. johnson y son de arg. s.a.          109531
# 1             clorox argentina s.a.          100861
# 2  s. c. johnson y son de arg. s.a.           89345
# 3  s. c. johnson y son de arg. s.a.           86737
# 4  s. c. johnson y son de arg. s.a.           72907
# 5  s. c. johnson y son de arg. s.a.           68809
# 6             clorox argentina s.a.           68083
# 7  s. c. johnson y son de arg. s.a.           66318
# 8  s. c. johnson y son de arg. s.a.           64371
# 9             clorox argentina s.a.           62046

# %%
product_grouped_top10['desc_producto']=product_grouped_top10['desc_producto'].replace(to_replace='ma�ana', value='manana', regex=True)

# %%
product_grouped_bottom10 = deodorants_df.groupby(
    ['id_producto', 'desc_producto', 'razon_social'])['venta_unidades'].sum().sort_values(
        ascending=False).nsmallest(10).reset_index()
product_grouped_bottom10
# Out:
#    id_producto                                      desc_producto  \
# 0       497936                                            missing
# 1       511325                                            missing
# 2       284013                                            missing
# 3       466069  glade toque aromatizante de ambientes campos l...
# 4       511324    pure aerosol air wick cherry blossom 250.00 mlt
# 5       511326       air wick pure aerosol soft cotton 250.00 mlt
# 6       485719                                            missing
# 7       284012        air wick citrico full rep.gratis 250.00 mlt
# 8       415268  freshmatic bosque magico aparato air wick lush...
# 9       164146                                            missing
#
#                        razon_social  venta_unidades
# 0                           unknown               0
# 1                           unknown            1983
# 2                           unknown            2562
# 3  s. c. johnson y son de arg. s.a.            2812
# 4  reckitt benckiser argentina s.a.            2927
# 5  reckitt benckiser argentina s.a.            3063
# 6                           unknown            3181
# 7  reckitt benckiser argentina s.a.            3650
# 8  reckitt benckiser argentina s.a.            4169
# 9                           unknown            5179

# %%
# concatenate the id_producto and desc_producto columns
product_grouped_bottom10['desc_producto'] = product_grouped_bottom10.apply(lambda row: 'id_prod:' + str( row['id_producto']) + ' - ' + row['desc_producto'], axis=1)

# %%
plot_sales_chart(product_grouped_top10,
                 'Top 10 desodorantes en aerosol más vendidos',
                 'ventas_desodorantes_top10',
                 'venta_unidades',
                 'desc_producto',
                 'venta_unidades',
                 'Ventas en Unidades',
                 'Descripción del Producto'
                 )

# %%
plot_sales_chart(product_grouped_bottom10,
                 'Top 10 desodorantes en aerosol menos vendidos',
                 'ventas_desodorantes_bot10',
                 'venta_unidades',
                 'desc_producto',
                 'venta_unidades',
                 'Ventas en Unidades',
                 'Descripción del Producto'
                 )

# %% [markdown]
# Esta lista de 16 productos tienen ventas zero y nunca han tenido una promoción por lo tanto las vamos a eliminar del dataset.

# %%
# Group the DataFrame by 'id_producto' and 'tiene_promo', and count the number of rows for each group
promo_counts = deodorants_df.groupby(['id_producto', 'tiene_promo'
                                      ]).size().reset_index(name='count')

# Create a Boolean Series indicating if a product has a count for both 'tiene_promo' values
has_both_promos = promo_counts.groupby(
    'id_producto')['tiene_promo'].count() == 2

# Filter the DataFrame to get the products that do not have a count for either 'tiene_promo' value
no_promos = promo_counts[~promo_counts['id_producto'].
                         isin(has_both_promos[has_both_promos].index)]

# Get the unique products IDs that do not have a count for either 'tiene_promo' value
no_promo_products = no_promos['id_producto'].unique()

no_promo_products

# %%
deodorants_without_promo = deodorants_df[deodorants_df['id_producto'].isin(
    no_promo_products)]
deodorants_without_promo

# %%
# filter the dataframe based on venta_unidades == 0
ventas_zero_df = deodorants_df[deodorants_df['venta_unidades'] == 0]

# group the resulting dataframe by id_producto and desc_producto, and sum the units sold
ventas_zero_grouped = ventas_zero_df.groupby(['id_producto', 'desc_producto'
                                              ])['venta_unidades'].sum()

# reset the index to convert the resulting series to a dataframe
ventas_zero_df = ventas_zero_grouped.reset_index()

ventas_zero_df

# %%
# print the resulting dataframe
result = ventas_zero_df[ventas_zero_df['desc_producto']=='unknown']
result

# %%
unknown = deodorants_df['desc_producto']
unknown

# %%
# filter ventas_zero_df based on the condition that id_producto is in no_promo_products list
ventas_zero_in_no_promos = ventas_zero_df[ventas_zero_df['id_producto'].isin(
    no_promo_products)]

# print the resulting dataframe
ventas_zero_in_no_promos

# %%
# create a boolean mask indicating which rows in deodorants_df have an id_producto that is present in ventas_zero_in_no_promos
mask = deodorants_df['id_producto'].isin(
    ventas_zero_in_no_promos['id_producto'])

# create a new dataframe without the rows that meet the condition
deodorants_df_filtered = deodorants_df[~mask]

# print the resulting dataframe
len(deodorants_df_filtered)

# %%
plot_sales_chart(
    product_grouped_top10,
    'Top 10 desodorantes con mayor volumen de ventas desde Julio 2016 hasta Julio 2019',
    'ventas_producto_top10')

# %%
import folium

# Combine the latitude and longitude columns into a list of locations
locations = [[lat, lon] for lat, lon in zip(deodorants_df['latitud'], deodorants_df['longitud'])]

# Define the bounds of the image
lat_min, lon_min = min(deodorants_df['latitud']), min(deodorants_df['longitud'])
lat_max, lon_max = max(deodorants_df['latitud']), max(deodorants_df['longitud'])
img_bounds = [[lat_min, lon_min], [lat_max, lon_max]]

# Create a map centered at the first location in the list
m = folium.Map(location=locations[0], zoom_start=5)

# Add markers to the map for each location in the list
for location in locations:
    folium.Marker(location=location).add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 18
#      15 for location in locations:
#      16     folium.Marker(location=location).add_to(m)
# ---> 18 m
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/IPython/core/displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/IPython/core/displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/IPython/core/formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/IPython/core/formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/IPython/core/formatters.py:342, in BaseFormatter.__call__(self, obj)
#     340     method = get_real_method(obj, self.print_method)
#     341     if method is not None:
# --> 342         return method()
#     343     return None
#     344 else:
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/folium/folium.py:321, in Map._repr_html_(self, **kwargs)
#     319     self._parent = None
#     320 else:
# --> 321     out = self._parent._repr_html_(**kwargs)
#     322 return out
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/branca/element.py:343, in Figure._repr_html_(self, **kwargs)
#     341 def _repr_html_(self, **kwargs):
#     342     """Displays the Figure in a Jupyter notebook."""
# --> 343     html = escape(self.render(**kwargs))
#     344     if self.height is None:
#     345         iframe = (
#     346             '<div style="width:{width};">'
#     347             '<div style="position:relative;width:100%;height:0;padding-bottom:{ratio};">'  # noqa
#    (...)
#     353             '</div></div>'
#     354         ).format(html=html, width=self.width, ratio=self.ratio)
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/branca/element.py:338, in Figure.render(self, **kwargs)
#     336 """Renders the HTML representation of the element."""
#     337 for name, child in self._children.items():
# --> 338     child.render(**kwargs)
#     339 return self._template.render(this=self, kwargs=kwargs)
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/folium/folium.py:403, in Map.render(self, **kwargs)
#     376 figure.header.add_child(
#     377     Element(
#     378         "<style>html, body {"
#    (...)
#     386     name="css_style",
#     387 )
#     389 figure.header.add_child(
#     390     Element(
#     391         "<style>#map {"
#    (...)
#     400     name="map_style",
#     401 )
# --> 403 super().render(**kwargs)
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/folium/elements.py:24, in JSCSSMixin.render(self, **kwargs)
#      21 for name, url in self.default_css:
#      22     figure.header.add_child(CssLink(url), name=name)
# ---> 24 super().render(**kwargs)
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/branca/element.py:645, in MacroElement.render(self, **kwargs)
#     641     figure.script.add_child(Element(script(self, kwargs)),
#     642                             name=self.get_name())
#     644 for name, element in self._children.items():
# --> 645     element.render(**kwargs)
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/folium/map.py:389, in Marker.render(self)
#     383 if self.location is None:
#     384     raise ValueError(
#     385         "{} location must be assigned when added directly to map.".format(
#     386             self._name
#     387         )
#     388     )
# --> 389 super().render()
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/branca/element.py:641, in MacroElement.render(self, **kwargs)
#     639 script = self._template.module.__dict__.get('script', None)
#     640 if script is not None:
# --> 641     figure.script.add_child(Element(script(self, kwargs)),
#     642                             name=self.get_name())
#     644 for name, element in self._children.items():
#     645     element.render(**kwargs)
#
# File /usr/local/anaconda3/envs/data_science/lib/python3.10/site-packages/branca/element.py:55, in Element.__init__(self, template, template_name)
#      53 def __init__(self, template=None, template_name=None):
#      54     self._name = 'Element'
# ---> 55     self._id = hexlify(urandom(16)).decode()
#      56     self._env = ENV
#      57     self._children = OrderedDict()
#
# KeyboardInterrupt:
