# %% [markdown]
# ## Análisis de las ventas de desodorantes en aerosol

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio
from plot_functions import plot_sales_chart, plot_piechart, plot_scatter, plot_box

# %%
deodorants_df = pd.read_csv("../data/deodorants_final_merged_v1.csv",
                            parse_dates=['fecha_trans'])

# %%
deodorants_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8272128 entries, 0 to 8272127
# Data columns (total 28 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   idb                     int64
#  1   id_producto             int64
#  2   fecha_trans             datetime64[ns]
#  3   stock_unidades          int64
#  4   venta_unidades          int64
#  5   precio_unitario         float64
#  6   sigue_prod_en_rol       int64
#  7   cd_abast                int64
#  8   mov_month               int64
#  9   mov_year                int64
#  10  mov_weekday             int64
#  11  ventas_estimadas_promo  int64
#  12  nro_prom                int64
#  13  duracion_promo          int64
#  14  id_cadena               int64
#  15  desc_cadena             object
#  16  longitud                float64
#  17  latitud                 float64
#  18  local                   int64
#  19  punto_dist              int64
#  20  desc_producto           object
#  21  razon_social            object
#  22  id_region               int64
#  23  dia_semana              object
#  24  is_weekend              int64
#  25  tiene_promo             int64
#  26  estacion                object
#  27  zona                    int64
# dtypes: datetime64[ns](1), float64(3), int64(19), object(5)
# memory usage: 1.7+ GB

# %%
# check for null or NaN values in each column
null_cols = deodorants_df.isnull().any()

# print columns with null or NaN values
print(null_cols[null_cols == True].index.tolist())
# Out:
# []

# %%
# Total sales with negative values
print(
    f'Total de ventas con valores negativos: {deodorants_df[deodorants_df["venta_unidades"] < 0]["venta_unidades"].count()}'
)
# Out:
# Total de ventas con valores negativos: 0

# %%
grouped_data = deodorants_df.groupby(['idb'
                                      ]).venta_unidades.count().reset_index()
grouped_data
# Out:
#       idb  venta_unidades
# 0     242           28452
# 1     247           56697
# 2     249           41863
# 3     252           21088
# 4     257           74383
# ..    ...             ...
# 137  9704           66231
# 138  9706           66730
# 139  9942           69347
# 140  9973           28658
# 141  9977           70925
#
# [142 rows x 2 columns]

# %%
# Before replacement
neg_count = deodorants_df[
    deodorants_df['stock_unidades'] < 0]['stock_unidades'].count()
print(f"Total de stock con valor negativo: {neg_count}")

# Replacing negative values with 0
deodorants_df.loc[deodorants_df['stock_unidades'] < 0, 'stock_unidades'] = 0

# After replacement
neg_count = deodorants_df[
    deodorants_df['stock_unidades'] < 0]['stock_unidades'].count()
print(
    f"Total de stock con valor negativo después de reemplazar con 0: {neg_count}"
)
# Out:
# Total de stock con valor negativo: 0
# Total de stock con valor negativo después de reemplazar con 0: 0

# %%
cols_num = [
    'venta_unidades', 'stock_unidades', 'duracion_promo',
    'ventas_estimadas_promo'
]
plot_box(deodorants_df,
         cols_num,
         title='Distribucción de las variables numéricas',
         figsize=(8, 10),
         nrows=4,
         savefig='valores_outliers')

# %%
import plotly.graph_objects as go
import pandas as pd

# Crear el histograma usando Plotly
fig = go.Figure(data=[go.Histogram(x=deodorants_df["venta_unidades"], nbinsx=20)])

# Personalizar el diseño del histograma
fig.update_layout(
    title="Histograma de Ventas de Desodorantes",
    xaxis_title="Ventas de unidades",
    yaxis_title="Frecuencia"
)

# Guardar la figura como una imagen
fig.write_image("images/ventas_hist.png")

# %%
def get_zone(latitude, longitude):
    """
    Assigns a zone number to a given latitude and longitude coordinate.

    Args:
        latitude (float): The latitude coordinate.
        longitude (float): The longitude coordinate.

    Returns:
        zone (int): The zone number for the given coordinates.
    """
    if latitude >= -34.0 and longitude >= -58.0:
        return 1
    elif latitude >= -34.0 and longitude < -58.0:
        return 2
    elif latitude < -34.0 and longitude >= -58.0:
        return 3
    else:
        return 4

# %%
deodorants_df['zona'] = deodorants_df.apply(
    lambda x: get_zone(x['latitud'], x['longitud']), axis=1)

# %%
ventas_by_zone_and_local = deodorants_df.groupby(
    ['zona', 'idb'])['venta_unidades'].sum().reset_index()
ventas_by_zone_and_local = ventas_by_zone_and_local.sort_values(
    by='venta_unidades', ascending=False)
ventas_by_zone_and_local
# Out:
#      zona   idb  venta_unidades
# 47      4  5202           95129
# 50      4  5206           85398
# 53      4  5211           68726
# 48      4  5204           62988
# 52      4  5208           58303
# ..    ...   ...             ...
# 35      4   285            2870
# 73      4  9011            2071
# 39      4   707            1018
# 61      4  5276             881
# 108     4  9157             794
#
# [142 rows x 3 columns]

# %%
ventas_by_zone = deodorants_df.groupby([
    'zona'
])['venta_unidades'].sum().reset_index().sort_values(by='venta_unidades',
                                                      ascending=False)
ventas_by_zone
# Out:
#    zona  venta_unidades
# 3     4         2166156
# 2     3          306298
# 1     2          122612
# 0     1           26624

# %%
# Filter the rows that need to be deleted
to_delete = deodorants_df.loc[
    (deodorants_df.venta_unidades == 0) & 
    (deodorants_df.desc_producto == 'missing') &
    (deodorants_df.razon_social == 'unknown') &
    (deodorants_df.stock_unidades == 0) &
    (deodorants_df.tiene_promo == 0) &
    (deodorants_df.nro_prom == 0.0) 
    
]

# Get the count of rows to be deleted
count_to_delete = len(to_delete)

# Delete the rows from the original dataframe
deodorants_df.drop(to_delete.index, inplace=True)

print(f'size before deleting: {len(deodorants_df)}')
print(f'Rows to delete: {count_to_delete}')
print(f'size after deleting: {len(deodorants_df)}')
# Out:
# size before deleting: 8272128
# Rows to delete: 0
# size after deleting: 8272128

# %%
filtered_df = deodorants_df[[
    'stock_unidades', 'venta_unidades', 'ventas_estimadas_promo',
    'precio_unitario', 'duracion_promo'
]]

# %%
stats = filtered_df.describe()

# %%
stats = stats.round(3)

# Create a Plotly table
table = go.Table(
    header=dict(values=['Statistic'] + list(stats.columns),
                fill_color="lightsteelblue",
                font=dict(color='white', size=14),
                align='center'),
    cells=dict(
        values=[['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max']] +
        [stats[col] for col in stats.columns],
        fill_color='#f2f2f2',
        font=dict(color='#404040', size=12),
        align='center'))

# Create a layout for the table
layout = go.Layout(width=900, height=500)

# Create a figure object with the table and layout
fig = go.Figure(data=[table], layout=layout)

# Save the figure as an image file
pio.write_image(fig, 'images/deodorants_stats.png')

# %%
deodorants_df.shape
# Out:
# (8272128, 28)

# %% [markdown]
# ### Preguntas

# %% [markdown]
# - ¿Cuáles son los productos con mayor volumen de ventas?

# %%
product_grouped_top10 = deodorants_df.groupby(
    ['id_producto', 'desc_producto',
     'razon_social'])['venta_unidades'].sum().sort_values(
         ascending=False).nlargest(10).reset_index()
product_grouped_top10
# Out:
#    id_producto                                      desc_producto  \
# 0       342686  glade desodorante de ambientes lavander nueva ...
# 1       240911           poett ambiental lavanda nuevo d 0.377 kg
# 2       429883  glade desodorante de ambientes ocean oasis nue...
# 3       249486      glade toque rep lavandax2 9gr/6 lavanda 9 grm
# 4       342745  glade desodorante de ambientes jazmin nueva fo...
# 5       228217      glade toque rep limon 12mlx12 repuesto 12 mlt
# 6       242234  poett ambiental suavidad de algodon nuevo d 0....
# 7       447299  glade desodorante de ambientes paraiso azul 1 ...
# 8       292949  glade toque desodorante de ambientes ma�ana ca...
# 9       242231         poett ambiental primavera nuevo d 0.377 kg
#
#                        razon_social  venta_unidades
# 0  s. c. johnson y son de arg. s.a.          109539
# 1             clorox argentina s.a.          100884
# 2  s. c. johnson y son de arg. s.a.           89352
# 3  s. c. johnson y son de arg. s.a.           86759
# 4  s. c. johnson y son de arg. s.a.           72912
# 5  s. c. johnson y son de arg. s.a.           68818
# 6             clorox argentina s.a.           68093
# 7  s. c. johnson y son de arg. s.a.           66328
# 8  s. c. johnson y son de arg. s.a.           64383
# 9             clorox argentina s.a.           62059

# %%
product_grouped_top10['desc_producto'] = product_grouped_top10[
    'desc_producto'].replace(to_replace='ma�ana', value='manana', regex=True)

# %%
product_grouped_bottom10 = deodorants_df.groupby(
    ['id_producto', 'desc_producto',
     'razon_social'])['venta_unidades'].sum().sort_values(
         ascending=False).nsmallest(10).reset_index()
product_grouped_bottom10
# Out:
#    id_producto                                      desc_producto  \
# 0       511325                                            missing
# 1       284013                                            missing
# 2       466069  glade toque aromatizante de ambientes campos l...
# 3       511324    pure aerosol air wick cherry blossom 250.00 mlt
# 4       511326       air wick pure aerosol soft cotton 250.00 mlt
# 5       485719                                            missing
# 6       284012        air wick citrico full rep.gratis 250.00 mlt
# 7       415268  freshmatic bosque magico aparato air wick lush...
# 8       164146                                            missing
# 9       469286  exotic scents full air wick freshmatic 250.00 mlt
#
#                        razon_social  venta_unidades
# 0                           unknown            1983
# 1                           unknown            2564
# 2  s. c. johnson y son de arg. s.a.            2816
# 3  reckitt benckiser argentina s.a.            2927
# 4  reckitt benckiser argentina s.a.            3063
# 5                           unknown            3181
# 6  reckitt benckiser argentina s.a.            3660
# 7  reckitt benckiser argentina s.a.            4176
# 8                           unknown            5182
# 9  reckitt benckiser argentina s.a.            5576

# %%
# concatenate the id_producto and desc_producto columns
product_grouped_bottom10['desc_producto'] = product_grouped_bottom10.apply(
    lambda row: 'id_prod:' + str(row['id_producto']) + ' - ' + row[
        'desc_producto'],
    axis=1)

# %%
plot_sales_chart(product_grouped_top10,
                 'Top 10 desodorantes en aerosol más vendidos',
                 'ventas_desodorantes_top10', 'venta_unidades',
                 'desc_producto', 'venta_unidades', 'Ventas en Unidades',
                 'Descripción del Producto')

# %%
plot_sales_chart(product_grouped_bottom10,
                 'Top 10 desodorantes en aerosol menos vendidos',
                 'ventas_desodorantes_bot10', 'venta_unidades',
                 'desc_producto', 'venta_unidades', 'Ventas en Unidades',
                 'Descripción del Producto')

# %%
grouped_zones = deodorants_df.groupby('idb')[['latitud', 'longitud', 'zona']].mean().reset_index()
grouped_zones
# Out:
#       idb    latitud   longitud  zona
# 0     242 -34.583210 -60.954190   4.0
# 1     247 -34.565259 -58.436583   4.0
# 2     249 -34.691168 -58.498985   4.0
# 3     252 -34.623613 -58.491471   4.0
# 4     257 -34.446043 -58.745098   4.0
# ..    ...        ...        ...   ...
# 137  9704 -38.377394 -60.272848   4.0
# 138  9706 -42.768281 -65.037972   4.0
# 139  9942 -38.012360 -57.565788   3.0
# 140  9973 -34.989573 -58.696112   4.0
# 141  9977 -34.564535 -58.451564   4.0
#
# [142 rows x 4 columns]

# %%
import folium
from folium.plugins import MarkerCluster

# create the map centered on Buenos Aires
ba_map = folium.Map(location=[-34.6037, -58.3816],
                    zoom_start=12,
                    tiles='OpenStreetMap')

# create a MarkerCluster for the markers
marker_cluster = MarkerCluster().add_to(ba_map)

# add a marker for each group in the "zona" column
for index, row in grouped_zones.iterrows():
    zona = row['zona']
    html = f"<div style='font-size: 12pt'>{zona}</div>"
    
    # add the marker to the MarkerCluster
    folium.Marker(location=[row['latitud'], row['longitud']],
                  popup=row['zona'],
                  icon=folium.Icon(icon='map-marker',
                                   prefix='fa',
                                   color='red'),
                  tooltip=html).add_to(marker_cluster)

# add a layer control to the map
folium.LayerControl().add_to(ba_map)

# save the map as a PNG file
ba_map.save('images/ba_map.png')

# display the map
ba_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d928b3da7ca469294148ed8bed83804e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d928b3da7ca469294148ed8bed83804e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d928b3da7ca469294148ed8bed83804e = L.map(
#                 &quot;map_d928b3da7ca469294148ed8bed83804e&quot;,
#                 {
#                     center: [-34.6037, -58.3816],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f052d0577bffaadb79c87bca15451c6f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d928b3da7ca469294148ed8bed83804e);
#
#
#             var marker_cluster_cbf85d7ed42b7bdda223efcbd6111524 = L.markerClusterGroup(
#                 {}
#             );
#             map_d928b3da7ca469294148ed8bed83804e.addLayer(marker_cluster_cbf85d7ed42b7bdda223efcbd6111524);
#
#
#             var marker_13ffbb505337062a8cfbc378fb1b9aae = L.marker(
#                 [-34.58321, -60.95419],
#                 {}
#             ).addTo(marker_cluster_cbf85d7ed42b7bdda223efcbd6111524);
#
#
#             var icon_38c45bc01b55921fc7ec443af91b0ea6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_13ffbb505337062a8cfbc378fb1b9aae.setIcon(icon_38c45bc01b55921fc7ec443af91b0ea6);
#
#
#         var popup_459d88b707e4db0f9c28f8afd843c72d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3466a949174ef2f833622b6b56dfe71d = $(`&lt;div id=&quot;html_3466a949174ef2f833622b6b56dfe71d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4.0&lt;/div&gt;`)[0];
#                 popup_459d88b707e4db0f9c28f8afd843c72d.setContent(html_3466a949174ef2f833622b6b56dfe71d);
#
#
#
#         marker_13ffbb505337062a8cfbc378fb1b9aae.bindPopup(popup_459d88b707e4db0f9c28f8afd843c72d)
#         ;
#
#
#
#
#             marker_13ffbb505337062a8cfbc378fb1b9aae.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;div style=&#x27;font-size: 12pt&#x27;&gt;4.0&lt;/div&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b3948d7104d9f2dad80b69b89d4e9766 = L.marker(
#                 [-34.565259, -58.436583],
#                 {}
#             ).addTo(marker_cluster_cbf85d7ed42b7bdda223efcbd6111524);
#
#
#             var icon_527a6b4bdcb2985ddcd5ebd8582da982 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b3948d7104d9f2dad80b69b89d4e9766.setIcon(icon_527a6b4bdcb2985ddcd5ebd8582da982);
#
#
#         var popup_1924c70d7f3f31820defb3d8e9800aaa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3087276889636bc535fdec415935e592 = $(`&lt;div id=&quot;html_3087276889636bc535fdec415935e592&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4.0&lt;/div&gt;`)[0];
#                 popup_1924c70d7f3f31820defb3d8e9800aaa.setContent(html_3087276889636bc535fdec415935e592);
#
#
#
#         marker_b3948d7104d9f2dad80b69b89d4e9766.bindPopup(popup_1924c70d7f3f31820defb3d8e9800aaa)
#         ;
#
#
#
#
#             marker_b3948d7104d9f2dad80b69b89d4e9766.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;div style=&#x27;font-size: 12pt&#x27;&gt;4.0&lt;/div&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_172f418e5aadfad5a3342c2cc8136dbd = L.marker(
#                 [-34.691168, -58.498985],
#                 {}
#             ).addTo(marker_cluster_cbf85d7ed42b7bdda223efcbd6111524);
#
#
#             var icon_b4caac9bf174bc3c1dc4f1a8c369c6ce = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quo

# %% [markdown]
# 2. ¿Cuál es el local con mayor volumen de ventas y en qué zona se encuentra?

# %%
sales_by_zone = deodorants_df.groupby([
    'idb', 'zona'
])['venta_unidades'].sum().sort_values(ascending=False).reset_index()
sales_by_zone
# Out:
#       idb  zona  venta_unidades
# 0    5202     4           95129
# 1    5206     4           85398
# 2    5211     4           68726
# 3    5204     4           62988
# 4    5208     4           58303
# ..    ...   ...             ...
# 137   285     4            2870
# 138  9011     4            2071
# 139   707     4            1018
# 140  5276     4             881
# 141  9157     4             794
#
# [142 rows x 3 columns]

# %%
local = deodorants_df[deodorants_df['idb']==5202]
local
# Out:
#           idb  id_producto fecha_trans  stock_unidades  venta_unidades  \
# 100      5202       468734  2019-07-14               6               0
# 188      5202       342679  2019-07-14              45               0
# 301      5202       387945  2019-07-14              45               0
# 339      5202       242234  2019-07-14              47               0
# 674      5202       342686  2019-07-14             177               0
# ...       ...          ...         ...             ...             ...
# 8271577  5202       468735  2018-01-10              30               2
# 8271774  5202       238241  2018-01-10              25               0
# 8271803  5202       292948  2018-01-10              21               0
# 8271810  5202       443520  2018-01-10              12               0
# 8271899  5202       238242  2018-01-10              21               0
#
#          precio_unitario  sigue_prod_en_rol  cd_abast  mov_month  mov_year  \
# 100               145.10                  1      9217          7      2019
# 188                43.35                  1      9217          7      2019
# 301               120.55                  1      9217          7      2019
# 339                40.47                  1      9217          7      2019
# 674                43.35                  1      9217          7      2019
# ...                  ...                ...       ...        ...       ...
# 8271577            73.78                  1      9217          1      2018
# 8271774            19.20                  1         0          1      2018
# 8271803            31.83                  1      9217          1      2018
# 8271810            33.95                  1         0          1      2018
# 8271899            19.20                  1      9217          1      2018
#
#          ...  local  punto_dist  \
# 100      ...      1           0
# 188      ...      1           0
# 301      ...      1           0
# 339      ...      1           0
# 674      ...      1           0
# ...      ...    ...         ...
# 8271577  ...      1           0
# 8271774  ...      1           0
# 8271803  ...      1           0
# 8271810  ...      1           0
# 8271899  ...      1           0
#
#                                              desc_producto  \
# 100      glade automatico 3 en 1 aromatizante de ambien...
# 188      glade desodorante de ambientes antitabaco nuev...
# 301      glade sense y spray aromatizante de ambiente e...
# 339      poett ambiental suavidad de algodon nuevo d 0....
# 674      glade desodorante de ambientes lavander nueva ...
# ...                                                    ...
# 8271577  glade automatico 3 en 1 aromatizante de ambien...
# 8271774           poett primavera refill ab nuevo 0.030 kg
# 8271803                                            missing
# 8271810                 poett natural blends frutal 450 gr
# 8271899                poett bebe refill ab nuevo 0.030 kg
#
#                              razon_social  id_region dia_semana  is_weekend  \
# 100      s. c. johnson y son de arg. s.a.          1     Sunday           1
# 188      s. c. johnson y son de arg. s.a.          1     Sunday           1
# 301      s. c. johnson y son de arg. s.a.          1     Sunday           1
# 339                 clorox argentina s.a.          1     Sunday           1
# 674      s. c. johnson y son de arg. s.a.          1     Sunday           1
# ...                                   ...        ...        ...         ...
# 8271577  s. c. johnson y son de arg. s.a.          1  Wednesday           0
# 8271774             clorox argentina s.a.          1  Wednesday           0
# 8271803                           unknown          0  Wednesday           0
# 8271810             clorox argentina s.a.          1  Wednesday           0
# 8271899             clorox argentina s.a.          1  Wednesday           0
#
#          tiene_promo  estacion  zona
# 100                0    verano     4
# 188                0    verano     4
# 301                0    verano     4
# 339                0    verano     4
# 674                0    verano     4
# ...              ...       ...   ...
# 8271577            0  invierno     4
# 8271774            0  invierno     4
# 8271803            0  invierno     4
# 8271810            0  invierno     4
# 8271899            0  invierno     4
#
# [85916 rows x 28 columns]

# %%
#voy aqui 
# Group the DataFrame by 'id_producto' and 'tiene_promo', and count the number of rows for each group
promo_counts = deod_df.groupby(['id_producto', 'tiene_promo'
                                      ]).size().reset_index(name='count')

# Create a Boolean Series indicating if a product has a count for both 'tiene_promo' values
has_both_promos = promo_counts.groupby(
    'id_producto')['tiene_promo'].count() == 2

# Filter the DataFrame to get the products that do not have a count for either 'tiene_promo' value
no_promos = promo_counts[~promo_counts['id_producto'].
                         isin(has_both_promos[has_both_promos].index)]

# Get the unique products IDs that do not have a count for either 'tiene_promo' value
no_promo_products = no_promos['id_producto'].unique()

no_promo_products

# %%
deodorants_without_promo = deod_df[deodorants_df['id_producto'].isin(
    no_promo_products)]
deodorants_without_promo

# %%
# filter the dataframe based on venta_unidades == 0
ventas_zero_df = deod_df[deodorants_df['venta_unidades'] == 0]

# group the resulting dataframe by id_producto and desc_producto, and sum the units sold
ventas_zero_grouped = ventas_zero_df.groupby(['id_producto', 'desc_producto'
                                              ])['venta_unidades'].sum()

# reset the index to convert the resulting series to a dataframe
ventas_zero_df = ventas_zero_grouped.reset_index()

ventas_zero_df
# Out:
#     id_producto                                      desc_producto  \
# 0        164146                                            missing
# 1        164149            glade toque rep lavanda 9gr/12 ar 9 grm
# 2        228217      glade toque rep limon 12mlx12 repuesto 12 mlt
# 3        228683           glade toque full limon 12mlx12 ar 12 mlt
# 4        238237               poett lavanda full ab nuevo 0.040 kg
# ..          ...                                                ...
# 87       507528  glade refrescantes ambientales-electricos auto...
# 88       507832  poett aerosol desodorante ambiental despertar ...
# 89       511324    pure aerosol air wick cherry blossom 250.00 mlt
# 90       511325                                            missing
# 91       511326       air wick pure aerosol soft cotton 250.00 mlt
#
#     venta_unidades
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ..             ...
# 87               0
# 88               0
# 89               0
# 90               0
# 91               0
#
# [92 rows x 3 columns]

# %%
# print the resulting dataframe
result = ventas_zero_df[ventas_zero_df['desc_producto'] == 'unknown']
result

# %%
unknown = deod_df['desc_producto']
unknown

# %%
# filter ventas_zero_df based on the condition that id_producto is in no_promo_products list
ventas_zero_in_no_promos = ventas_zero_df[ventas_zero_df['id_producto'].isin(
    no_promo_products)]

# print the resulting dataframe
ventas_zero_in_no_promos

# %%
# create a boolean mask indicating which rows in deodorants_df have an id_producto that is present in ventas_zero_in_no_promos
mask = deod_df['id_producto'].isin(
    ventas_zero_in_no_promos['id_producto'])

# create a new dataframe without the rows that meet the condition
deodorants_df_filtered = deod_df[~mask]

# print the resulting dataframe
len(deodorants_df_filtered)
